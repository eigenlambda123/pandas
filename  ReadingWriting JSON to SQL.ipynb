# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv', index_col='ResponseId')
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='qname')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.head()
# Out:
#                                 MainBranch                 Age  \
# ResponseId
# 1           I am a developer by profession  Under 18 years old
# 2           I am a developer by profession     35-44 years old
# 3           I am a developer by profession     45-54 years old
# 4                    I am learning to code     18-24 years old
# 5           I am a developer by profession     18-24 years old
#
#                      Employment RemoteWork   Check  \
# ResponseId
# 1           Employed, full-time     Remote  Apples
# 2           Employed, full-time     Remote  Apples
# 3           Employed, full-time     Remote  Apples
# 4            Student, full-time        NaN  Apples
# 5            Student, full-time        NaN  Apples
#
#                                              CodingActivities  \
# ResponseId
# 1                                                       Hobby
# 2           Hobby;Contribute to open-source projects;Other...
# ...

# %%
filt = (df['Country'] == 'India')
india_df = df.loc[filt]
india_df.head()
# Out:
#                                                    MainBranch  \
# ResponseId
# 18                             I am a developer by profession
# 59          I am not primarily a developer, but I write co...
# 76                                      I am learning to code
# 90                                      I am learning to code
# 97                             I am a developer by profession
#
#                         Age  \
# ResponseId
# 18          18-24 years old
# 59          18-24 years old
# 76          25-34 years old
# 90          25-34 years old
# 97          25-34 years old
#
#                                                    Employment RemoteWork  \
# ResponseId
# 18          Independent contractor, freelancer, or self-em...     Remote
# 59                                         Student, full-time        NaN
# 76                         Not employed, but looking for work        NaN
# 90                                        Employed, full-time  In-person
# ...

# %%
india_df.to_json('data/modified.json')

# %%
test = pd.read_json('data/modified.json')

# %%
test
# Out:
#                                               MainBranch              Age  \
# 18                        I am a developer by profession  18-24 years old
# 59     I am not primarily a developer, but I write co...  18-24 years old
# 76                                 I am learning to code  25-34 years old
# 90                                 I am learning to code  25-34 years old
# 97                        I am a developer by profession  25-34 years old
# ...                                                  ...              ...
# 65340  I am not primarily a developer, but I write co...  18-24 years old
# 65384                              I am learning to code  18-24 years old
# 65414                              I am learning to code  18-24 years old
# 65416                        I code primarily as a hobby  35-44 years old
# 65429                     I am a developer by profession  25-34 years old
#
#                                               Employment RemoteWork   Check  \
# ...

# %%
from sqlalchemy import create_engine
import psycopg2

# %%
engine = create_engine('postgresql://dbuser:dbpass@localhost:5432/sample_db')

# %%
india_df.to_sql('sample_table', engine, if_exist='replace')

# %%
sql_df = pd.read_sql('sample_table', engine, index=col='ResponseId')

# %%
sql_df.head()

# %%
sql_df = pd.read_sql_query('SELECT * FROM sample_table', engine, index=col='ResponseId')
