# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv', index_col='ResponseId')
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='qname')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.head()
# Out:
#                                 MainBranch                 Age  \
# ResponseId
# 1           I am a developer by profession  Under 18 years old
# 2           I am a developer by profession     35-44 years old
# 3           I am a developer by profession     45-54 years old
# 4                    I am learning to code     18-24 years old
# 5           I am a developer by profession     18-24 years old
#
#                      Employment RemoteWork   Check  \
# ResponseId
# 1           Employed, full-time     Remote  Apples
# 2           Employed, full-time     Remote  Apples
# 3           Employed, full-time     Remote  Apples
# 4            Student, full-time        NaN  Apples
# 5            Student, full-time        NaN  Apples
#
#                                              CodingActivities  \
# ResponseId
# 1                                                       Hobby
# 2           Hobby;Contribute to open-source projects;Other...
# 3           Hobby;Contribute to open-source projects;Other...
# 4                                                         NaN
# 5                                                         NaN
#
#                                                       EdLevel  \
# ResponseId
# 1                                   Primary/elementary school
# 2                Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3             Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4           Some college/university study without earning ...
# 5           Secondary school (e.g. American high school, G...
#
#                                                     LearnCode  \
# ResponseId
# 1                                      Books / Physical media
# 2           Books / Physical media;Colleague;On the job tr...
# 3           Books / Physical media;Colleague;On the job tr...
# 4           Other online resources (e.g., videos, blogs, f...
# 5           Other online resources (e.g., videos, blogs, f...
#
#                                               LearnCodeOnline  \
# ResponseId
# 1                                                         NaN
# 2           Technical documentation;Blogs;Books;Written Tu...
# 3           Technical documentation;Blogs;Books;Written Tu...
# 4           Stack Overflow;How-to videos;Interactive tutorial
# 5           Technical documentation;Blogs;Written Tutorial...
#
#                                                       TechDoc YearsCode  \
# ResponseId
# 1                                                         NaN       NaN
# 2           API document(s) and/or SDK document(s);User gu...        20
# 3           API document(s) and/or SDK document(s);User gu...        37
# 4                                                         NaN         4
# 5           API document(s) and/or SDK document(s);User gu...         9
#
#            YearsCodePro                DevType OrgSize PurchaseInfluence  \
# ResponseId
# 1                   NaN                    NaN     NaN               NaN
# 2                    17  Developer, full-stack     NaN               NaN
# 3                    27   Developer Experience     NaN               NaN
# 4                   NaN  Developer, full-stack     NaN               NaN
# 5                   NaN  Developer, full-stack     NaN               NaN
#
#            BuyNewTool BuildvsBuy TechEndorse  \
# ResponseId
# 1                 NaN        NaN         NaN
# 2                 NaN        NaN         NaN
# 3                 NaN        NaN         NaN
# 4                 NaN        NaN         NaN
# 5                 NaN        NaN         NaN
#
#                                                       Country Currency  \
# ResponseId
# 1                                    United States of America      NaN
# 2           United Kingdom of Great Britain and Northern I...      NaN
# 3           United Kingdom of Great Britain and Northern I...      NaN
# 4                                                      Canada      NaN
# 5                                                      Norway      NaN
#
#             CompTotal                             LanguageHaveWorkedWith  \
# ResponseId
# 1                 NaN                                                NaN
# 2                 NaN  Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 3                 NaN                                                 C#
# 4                 NaN  C;C++;HTML/CSS;Java;JavaScript;PHP;PowerShell;...
# 5                 NaN            C++;HTML/CSS;JavaScript;Lua;Python;Rust
#
#                                        LanguageWantToWorkWith  \
# ResponseId
# 1                                                         NaN
# 2           Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 3                                                          C#
# 4           HTML/CSS;Java;JavaScript;PowerShell;Python;SQL...
# 5                          C++;HTML/CSS;JavaScript;Lua;Python
#
#                                               LanguageAdmired  \
# ResponseId
# 1                                                         NaN
# 2           Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 3                                                          C#
# 4           HTML/CSS;Java;JavaScript;PowerShell;Python;SQL...
# 5                          C++;HTML/CSS;JavaScript;Lua;Python
#
#                      DatabaseHaveWorkedWith      DatabaseWantToWorkWith  \
# ResponseId
# 1                                       NaN                         NaN
# 2               Dynamodb;MongoDB;PostgreSQL                  PostgreSQL
# 3                Firebase Realtime Database  Firebase Realtime Database
# 4           MongoDB;MySQL;PostgreSQL;SQLite    MongoDB;MySQL;PostgreSQL
# 5                         PostgreSQL;SQLite           PostgreSQL;SQLite
#
#                        DatabaseAdmired  \
# ResponseId
# 1                                  NaN
# 2                           PostgreSQL
# 3           Firebase Realtime Database
# 4             MongoDB;MySQL;PostgreSQL
# 5                    PostgreSQL;SQLite
#
#                               PlatformHaveWorkedWith  \
# ResponseId
# 1                                                NaN
# 2           Amazon Web Services (AWS);Heroku;Netlify
# 3                                       Google Cloud
# 4            Amazon Web Services (AWS);Fly.io;Heroku
# 5                                                NaN
#
#                               PlatformWantToWorkWith  \
# ResponseId
# 1                                                NaN
# 2           Amazon Web Services (AWS);Heroku;Netlify
# 3                                       Google Cloud
# 4                   Amazon Web Services (AWS);Vercel
# 5                                                NaN
#
#                                      PlatformAdmired  \
# ResponseId
# 1                                                NaN
# 2           Amazon Web Services (AWS);Heroku;Netlify
# 3                                       Google Cloud
# 4                          Amazon Web Services (AWS)
# 5                                                NaN
#
#                             WebframeHaveWorkedWith  \
# ResponseId
# 1                                              NaN
# 2                    Express;Next.js;Node.js;React
# 3                                     ASP.NET CORE
# 4           jQuery;Next.js;Node.js;React;WordPress
# 5                                              NaN
#
#                       WebframeWantToWorkWith               WebframeAdmired  \
# ResponseId
# 1                                        NaN                           NaN
# 2           Express;Htmx;Node.js;React;Remix         Express;Node.js;React
# 3                               ASP.NET CORE                  ASP.NET CORE
# 4               jQuery;Next.js;Node.js;React  jQuery;Next.js;Node.js;React
# 5                                        NaN                           NaN
#
#              EmbeddedHaveWorkedWith EmbeddedWantToWorkWith    EmbeddedAdmired  \
# ResponseId
# 1                               NaN                    NaN                NaN
# 2                               NaN                    NaN                NaN
# 3                       Rasberry Pi            Rasberry Pi        Rasberry Pi
# 4                       Rasberry Pi                    NaN                NaN
# 5           CMake;Cargo;Rasberry Pi      CMake;Rasberry Pi  CMake;Rasberry Pi
#
#                                      MiscTechHaveWorkedWith  \
# ResponseId
# 1                                                       NaN
# 2                                                       NaN
# 3           .NET (5+) ;.NET Framework (1.0 - 4.8);.NET MAUI
# 4                              NumPy;Pandas;Ruff;TensorFlow
# 5                                                       NaN
#
#                                      MiscTechWantToWorkWith  \
# ResponseId
# 1                                                       NaN
# 2                                                       NaN
# 3           .NET (5+) ;.NET Framework (1.0 - 4.8);.NET MAUI
# 4                                                       NaN
# 5                                                       NaN
#
#                                             MiscTechAdmired  \
# ResponseId
# 1                                                       NaN
# 2                                                       NaN
# 3           .NET (5+) ;.NET Framework (1.0 - 4.8);.NET MAUI
# 4                                                       NaN
# 5                                                       NaN
#
#                                 ToolsTechHaveWorkedWith  \
# ResponseId
# 1                                                   NaN
# 2           Docker;Homebrew;Kubernetes;npm;Vite;Webpack
# 3                                               MSBuild
# 4                                        Docker;npm;Pip
# 5                                          APT;Make;npm
#
#                                 ToolsTechWantToWorkWith  \
# ResponseId
# 1                                                   NaN
# 2           Docker;Homebrew;Kubernetes;npm;Vite;Webpack
# 3                                               MSBuild
# 4                                 Docker;Kubernetes;npm
# 5                                              APT;Make
#
#                                        ToolsTechAdmired  ... AINextNo change  \
# ResponseId                                               ...
# 1                                                   NaN  ...             NaN
# 2           Docker;Homebrew;Kubernetes;npm;Vite;Webpack  ...             NaN
# 3                                               MSBuild  ...             NaN
# 4                                            Docker;npm  ...             NaN
# 5                                              APT;Make  ...             NaN
#
#            AINextMore integrated AINextLess integrated  \
# ResponseId
# 1                            NaN                   NaN
# 2                            NaN                   NaN
# 3                            NaN                   NaN
# 4                            NaN                   NaN
# 5                            NaN                   NaN
#
#            AINextMuch less integrated AIThreat  \
# ResponseId
# 1                                 NaN      NaN
# 2                                 NaN      NaN
# 3                                 NaN      NaN
# 4                                 NaN       No
# 5                                 NaN      NaN
#
#                                                      AIEthics  \
# ResponseId
# 1                                                         NaN
# 2                                                         NaN
# 3                                                         NaN
# 4           Circulating misinformation or disinformation;M...
# 5                                                         NaN
#
#                                  AIChallenges TBranch                  ICorPM  \
# ResponseId
# 1                                         NaN      No                     NaN
# 2                                         NaN     Yes  Individual contributor
# 3                                         NaN      No                     NaN
# 4           Don’t trust the output or answers     NaN                     NaN
# 5                                         NaN     NaN                     NaN
#
#            WorkExp Knowledge_1 Knowledge_2 Knowledge_3 Knowledge_4  \
# ResponseId
# 1              NaN         NaN         NaN         NaN         NaN
# 2             17.0       Agree    Disagree       Agree       Agree
# 3              NaN         NaN         NaN         NaN         NaN
# 4              NaN         NaN         NaN         NaN         NaN
# 5              NaN         NaN         NaN         NaN         NaN
#
#            Knowledge_5                 Knowledge_6 Knowledge_7 Knowledge_8  \
# ResponseId
# 1                  NaN                         NaN         NaN         NaN
# 2                Agree  Neither agree nor disagree    Disagree       Agree
# 3                  NaN                         NaN         NaN         NaN
# 4                  NaN                         NaN         NaN         NaN
# 5                  NaN                         NaN         NaN         NaN
#
#            Knowledge_9 Frequency_1 Frequency_2 Frequency_3 TimeSearching  \
# ResponseId
# 1                  NaN         NaN         NaN         NaN           NaN
# 2                Agree         NaN         NaN         NaN           NaN
# 3                  NaN         NaN         NaN         NaN           NaN
# 4                  NaN         NaN         NaN         NaN           NaN
# 5                  NaN         NaN         NaN         NaN           NaN
#
#            TimeAnswering Frustration ProfessionalTech ProfessionalCloud  \
# ResponseId
# 1                    NaN         NaN              NaN               NaN
# 2                    NaN         NaN              NaN               NaN
# 3                    NaN         NaN              NaN               NaN
# 4                    NaN         NaN              NaN               NaN
# 5                    NaN         NaN              NaN               NaN
#
#            ProfessionalQuestion Industry JobSatPoints_1 JobSatPoints_4  \
# ResponseId
# 1                           NaN      NaN            NaN            NaN
# 2                           NaN      NaN            0.0            0.0
# 3                           NaN      NaN            NaN            NaN
# 4                           NaN      NaN            NaN            NaN
# 5                           NaN      NaN            NaN            NaN
#
#            JobSatPoints_5 JobSatPoints_6 JobSatPoints_7 JobSatPoints_8  \
# ResponseId
# 1                     NaN            NaN            NaN            NaN
# 2                     0.0            0.0            0.0            0.0
# 3                     NaN            NaN            NaN            NaN
# 4                     NaN            NaN            NaN            NaN
# 5                     NaN            NaN            NaN            NaN
#
#            JobSatPoints_9 JobSatPoints_10 JobSatPoints_11  \
# ResponseId
# 1                     NaN             NaN             NaN
# 2                     0.0             0.0             0.0
# 3                     NaN             NaN             NaN
# 4                     NaN             NaN             NaN
# 5                     NaN             NaN             NaN
#
#                      SurveyLength SurveyEase ConvertedCompYearly JobSat
# ResponseId
# 1                             NaN        NaN                 NaN    NaN
# 2                             NaN        NaN                 NaN    NaN
# 3           Appropriate in length       Easy                 NaN    NaN
# 4                        Too long       Easy                 NaN    NaN
# 5                       Too short       Easy                 NaN    NaN
#
# [5 rows x 113 columns]

# %%
schema_df
# Out:
#                     qid                                           question  \
# qname
# MainBranch         QID2  Which of the following options best describes ...
# Age              QID127                                 What is your age?*
# Employment       QID296  Which of the following best describes your cur...
# RemoteWork       QID308  Which best describes your current work situation?
# Check            QID341  Just checking to make sure you are paying atte...
# ...                 ...                                                ...
# JobSatPoints_7   QID337  Learning and using new technology, including p...
# JobSatPoints_8   QID337  Designing and building environments, databases...
# JobSatPoints_9   QID337  Being a power user of a tool, developer langua...
# JobSatPoints_10  QID337       Working with new and/or top-quality hardware
# JobSatPoints_11  QID337  A well-staffed/sourced internal network that m...
#
#                 force_resp type selector
# qname
# MainBranch            True   MC     SAVR
# Age                   True   MC     SAVR
# Employment            True   MC     MAVR
# RemoteWork           False   MC     SAVR
# Check                 True   MC     SAVR
# ...                    ...  ...      ...
# JobSatPoints_7         NaN   MC     MAVR
# JobSatPoints_8         NaN   MC     MAVR
# JobSatPoints_9         NaN   MC     MAVR
# JobSatPoints_10        NaN   MC     MAVR
# JobSatPoints_11        NaN   MC     MAVR
#
# [87 rows x 5 columns]

# %%
df['CompTotal'].median()
# Out:
# np.float64(110000.0)

# %%
df.median(numeric_only=True)
# Out:
# CompTotal              110000.0
# WorkExp                     9.0
# JobSatPoints_1             10.0
# JobSatPoints_4              0.0
# JobSatPoints_5              0.0
# JobSatPoints_6             20.0
# JobSatPoints_7             15.0
# JobSatPoints_8             10.0
# JobSatPoints_9              5.0
# JobSatPoints_10             0.0
# JobSatPoints_11             0.0
# ConvertedCompYearly     65000.0
# JobSat                      7.0
# dtype: float64

# %%
df.describe()
# Out:
#            CompTotal       WorkExp  JobSatPoints_1  JobSatPoints_4  \
# count   3.374000e+04  29658.000000    29324.000000    29393.000000
# mean   2.963841e+145     11.466957       18.581094        7.522140
# std    5.444117e+147      9.168709       25.966221       18.422661
# min     0.000000e+00      0.000000        0.000000        0.000000
# 25%     6.000000e+04      4.000000        0.000000        0.000000
# 50%     1.100000e+05      9.000000       10.000000        0.000000
# 75%     2.500000e+05     16.000000       22.000000        5.000000
# max    1.000000e+150     50.000000      100.000000      100.000000
#
#        JobSatPoints_5  JobSatPoints_6  JobSatPoints_7  JobSatPoints_8  \
# count    29411.000000    29450.000000     29448.00000    29456.000000
# mean        10.060857       24.343232        22.96522       20.278165
# std         21.833836       27.089360        27.01774       26.108110
# min          0.000000        0.000000         0.00000        0.000000
# 25%          0.000000        0.000000         0.00000        0.000000
# 50%          0.000000       20.000000        15.00000       10.000000
# 75%         10.000000       30.000000        30.00000       25.000000
# max        100.000000      100.000000       100.00000      100.000000
#
#        JobSatPoints_9  JobSatPoints_10  JobSatPoints_11  ConvertedCompYearly  \
# count    29456.000000     29450.000000     29445.000000         2.343500e+04
# mean        16.169432        10.955713         9.953948         8.615529e+04
# std         24.845032        22.906263        21.775652         1.867570e+05
# min          0.000000         0.000000         0.000000         1.000000e+00
# 25%          0.000000         0.000000         0.000000         3.271200e+04
# 50%          5.000000         0.000000         0.000000         6.500000e+04
# 75%         20.000000        10.000000        10.000000         1.079715e+05
# max        100.000000       100.000000       100.000000         1.625660e+07
#
#              JobSat
# count  29126.000000
# mean       6.935041
# std        2.088259
# min        0.000000
# 25%        6.000000
# 50%        7.000000
# 75%        8.000000
# max       10.000000

# %%
df['CompTotal'].count()
# Out:
# np.int64(33740)

# %%
df['CodingActivities'].value_counts()
# Out:
# CodingActivities
# Hobby                                                                                                                                                                              9993
# I don’t code outside of work                                                                                                                                                       6508
# Hobby;Professional development or self-paced learning from online courses                                                                                                          6203
# Hobby;Contribute to open-source projects                                                                                                                                           3732
# Professional development or self-paced learning from online courses                                                                                                                3120
#                                                                                                                                                                                    ...
# Hobby;Contribute to open-source projects;Other (please specify):;School or academic work;Freelance/contract work                                                                      1
# Other (please specify):;Bootstrapping a business;School or academic work                                                                                                              1
# Contribute to open-source projects;Other (please specify):;Bootstrapping a business;School or academic work;Professional development or self-paced learning from online courses       1
# Hobby;Contribute to open-source projects;Other (please specify):;Bootstrapping a business;School or academic work                                                                     1
# Hobby;Other (please specify):;Bootstrapping a business;School or academic work;Professional development or self-paced learning from online courses;Freelance/contract work            1
# Name: count, Length: 118, dtype: int64

# %%
df['Employment']
# Out:
# ResponseId
# 1        Employed, full-time
# 2        Employed, full-time
# 3        Employed, full-time
# 4         Student, full-time
# 5         Student, full-time
#                 ...
# 65433    Employed, full-time
# 65434    Employed, full-time
# 65435    Employed, full-time
# 65436    Employed, full-time
# 65437     Student, full-time
# Name: Employment, Length: 65437, dtype: object

# %%
schema_df.loc['DevType']
# Out:
# qid                                                       QID31
# question      Which of the following describes your current ...
# force_resp                                                False
# type                                                         MC
# selector                                                   SAVR
# Name: DevType, dtype: object

# %%
df['DevType'].value_counts(normalize=True)
# Out:
# DevType
# Developer, full-stack                            0.307175
# Developer, back-end                              0.167012
# Student                                          0.085827
# Developer, front-end                             0.056338
# Developer, desktop or enterprise applications    0.041938
# Other (please specify):                          0.041349
# Developer, mobile                                0.033998
# Developer, embedded applications or devices      0.027303
# Engineering manager                              0.021448
# Academic researcher                              0.020826
# Data engineer                                    0.018807
# Data scientist or machine learning specialist    0.017226
# DevOps specialist                                0.017142
# Research & Development role                      0.015863
# Senior Executive (C-Suite, VP, etc.)             0.014080
# Developer, game or graphics                      0.011877
# Cloud infrastructure engineer                    0.010665
# System administrator                             0.009286
# Developer, AI                                    0.009134
# Developer, QA or test                            0.008832
# Data or business analyst                         0.008798
# Project manager                                  0.007032
# Security professional                            0.005989
# Educator                                         0.005972
# Scientist                                        0.005585
# Engineer, site reliability                       0.005215
# Product manager                                  0.004878
# Blockchain                                       0.003953
# Developer Experience                             0.003768
# Hardware Engineer                                0.003364
# Designer                                         0.003062
# Database administrator                           0.002877
# Developer Advocate                               0.001766
# Marketing or sales professional                  0.001615
# Name: proportion, dtype: float64

# %%
df['Country'].value_counts()
# Out:
# Country
# United States of America                                11095
# Germany                                                  4947
# India                                                    4231
# United Kingdom of Great Britain and Northern Ireland     3224
# Ukraine                                                  2672
#                                                         ...
# Micronesia, Federated States of...                          1
# Nauru                                                       1
# Chad                                                        1
# Djibouti                                                    1
# Solomon Islands                                             1
# Name: count, Length: 185, dtype: int64

# %%
country_grp = df.groupby(['Country'])

# %%
country_grp

# %%
country_grp.get_group('Philippines')
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_10968\3094930765.py:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   country_grp.get_group('Philippines')
#                                                    MainBranch  \
# ResponseId
# 14          I used to be a developer by profession, but no...
# 30                             I am a developer by profession
# 174                            I am a developer by profession
# 419                            I am a developer by profession
# 1023                           I am a developer by profession
# ...                                                       ...
# 60421                          I am a developer by profession
# 60751                          I am a developer by profession
# 61783                             I code primarily as a hobby
# 63142                          I am a developer by profession
# 63277                          I am a developer by profession
#
#                            Age  \
# ResponseId
# 14             35-44 years old
# 30             25-34 years old
# 174            18-24 years old
# 419            35-44 years old
# 1023           25-34 years old
# ...                        ...
# 60421          25-34 years old
# 60751          25-34 years old
# 61783       Under 18 years old
# 63142          35-44 years old
# 63277          25-34 years old
#
#                                                    Employment  \
# ResponseId
# 14                     Not employed, and not looking for work
# 30                                        Employed, full-time
# 174                                       Employed, full-time
# 419         Independent contractor, freelancer, or self-em...
# 1023        Not employed, but looking for work;Not employe...
# ...                                                       ...
# 60421                                     Employed, full-time
# 60751                      Not employed, but looking for work
# 61783                                      Student, part-time
# 63142       Independent contractor, freelancer, or self-em...
# 63277                                     Employed, full-time
#
#                                       RemoteWork   Check  \
# ResponseId
# 14                                           NaN  Apples
# 30                                        Remote  Apples
# 174         Hybrid (some remote, some in-person)  Apples
# 419         Hybrid (some remote, some in-person)  Apples
# 1023                                         NaN  Apples
# ...                                          ...     ...
# 60421                                     Remote  Apples
# 60751                                        NaN  Apples
# 61783                                        NaN  Apples
# 63142                                     Remote  Apples
# 63277                                     Remote  Apples
#
#                           CodingActivities  \
# ResponseId
# 14                                     NaN
# 30            I don’t code outside of work
# 174                                  Hobby
# 419         Hobby;Bootstrapping a business
# 1023                                   NaN
# ...                                    ...
# 60421                                Hobby
# 60751                                  NaN
# 61783                                  NaN
# 63142              Freelance/contract work
# 63277             Bootstrapping a business
#
#                                                       EdLevel  \
# ResponseId
# 14               Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 30               Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 174              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 419              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 1023             Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                       ...
# 60421            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 60751            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 61783       Some college/university study without earning ...
# 63142            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 63277       Some college/university study without earning ...
#
#                                                     LearnCode  \
# ResponseId
# 14          Colleague;Other online resources (e.g., videos...
# 30          Colleague;Other online resources (e.g., videos...
# 174         Colleague;On the job training;Other online res...
# 419         Books / Physical media;Colleague;Other online ...
# 1023        Other online resources (e.g., videos, blogs, f...
# ...                                                       ...
# 60421       On the job training;Other online resources (e....
# 60751       Colleague;On the job training;Other online res...
# 61783                                 Other (please specify):
# 63142       On the job training;Other online resources (e....
# 63277       On the job training;Other online resources (e....
#
#                                               LearnCodeOnline  \
# ResponseId
# 14          Technical documentation;Blogs;Stack Overflow;I...
# 30               Technical documentation;Blogs;Stack Overflow
# 174         Stack Overflow;Social Media;How-to videos;AI;C...
# 419         Technical documentation;Blogs;Books;Written Tu...
# 1023        Technical documentation;Blogs;Written Tutorial...
# ...                                                       ...
# 60421       Technical documentation;Stack Overflow;Coding ...
# 60751       Technical documentation;Written Tutorials;Stac...
# 61783                                                     NaN
# 63142       Written Tutorials;Stack Overflow;Social Media;...
# 63277       Blogs;Written Tutorials;Stack Overflow;Coding ...
#
#                                                       TechDoc YearsCode  \
# ResponseId
# 14          API document(s) and/or SDK document(s);User gu...        20
# 30          API document(s) and/or SDK document(s);User gu...         9
# 174                                                       NaN         5
# 419         API document(s) and/or SDK document(s);User gu...        22
# 1023        API document(s) and/or SDK document(s);User gu...        13
# ...                                                       ...       ...
# 60421       API document(s) and/or SDK document(s);User gu...        13
# 60751       API document(s) and/or SDK document(s);AI-powe...         9
# 61783                                                     NaN         3
# 63142                                                     NaN        25
# 63277                                                     NaN         6
#
#                 YearsCodePro                  DevType               OrgSize  \
# ResponseId
# 14                       NaN  Other (please specify):                   NaN
# 30                         6    Developer, full-stack                   NaN
# 174         Less than 1 year      Developer, back-end                   NaN
# 419                       17      Engineering manager                   NaN
# 1023                       3  Other (please specify):                   NaN
# ...                      ...                      ...                   ...
# 60421                      9    Developer, full-stack  500 to 999 employees
# 60751                      5  Other (please specify):                   NaN
# 61783                    NaN                  Student                   NaN
# 63142                     18        Developer, mobile      2 to 9 employees
# 63277                      6    Developer, full-stack      2 to 9 employees
#
#                 PurchaseInfluence  \
# ResponseId
# 14                            NaN
# 30                            NaN
# 174                           NaN
# 419                           NaN
# 1023                          NaN
# ...                           ...
# 60421       I have some influence
# 60751                         NaN
# 61783                         NaN
# 63142       I have some influence
# 63277       I have some influence
#
#                                                    BuyNewTool  \
# ResponseId
# 14                                                        NaN
# 30                                                        NaN
# 174                                                       NaN
# 419                                                       NaN
# 1023                                                      NaN
# ...                                                       ...
# 60421       Start a free trial;Visit developer communities...
# 60751                                                     NaN
# 61783                                                     NaN
# 63142       Ask developers I know/work with;Read ratings o...
# 63277                                      Start a free trial
#
#                                                    BuildvsBuy  \
# ResponseId
# 14                                                        NaN
# 30                                                        NaN
# 174                                                       NaN
# 419                                                       NaN
# 1023                                                      NaN
# ...                                                       ...
# 60421       Out-of-the-box is ready to go with little need...
# 60751                                                     NaN
# 61783                                                     NaN
# 63142       Is ready-to-go but also customizable for growt...
# 63277       Is ready-to-go but also customizable for growt...
#
#                                                   TechEndorse      Country  \
# ResponseId
# 14                                                        NaN  Philippines
# 30                                                        NaN  Philippines
# 174                                                       NaN  Philippines
# 419                                                       NaN  Philippines
# 1023                                                      NaN  Philippines
# ...                                                       ...          ...
# 60421       APIs;Integrated developer community;Quality su...  Philippines
# 60751                                                     NaN  Philippines
# 61783                                                     NaN  Philippines
# 63142       APIs;Integrated developer community;Reputation...  Philippines
# 63277       APIs;Customization;Integrated developer commun...  Philippines
#
#                         Currency  CompTotal  \
# ResponseId
# 14                           NaN        NaN
# 30                           NaN        NaN
# 174                          NaN        NaN
# 419                          NaN        NaN
# 1023                         NaN        NaN
# ...                          ...        ...
# 60421       PHP\tPhilippine peso        NaN
# 60751                        NaN        NaN
# 61783                        NaN        NaN
# 63142       PHP\tPhilippine peso        NaN
# 63277       PHP\tPhilippine peso   110000.0
#
#                                        LanguageHaveWorkedWith  \
# ResponseId
# 14                                                 PHP;Python
# 30                                 C#;HTML/CSS;JavaScript;SQL
# 174                                       HTML/CSS;JavaScript
# 419         Bash/Shell (all shells);Groovy;HTML/CSS;Java;J...
# 1023                   C#;C++;HTML/CSS;JavaScript;Python;Rust
# ...                                                       ...
# 60421       Go;HTML/CSS;Java;JavaScript;PHP;Python;SQL;Typ...
# 60751                             HTML/CSS;JavaScript;PHP;SQL
# 61783                                                     NaN
# 63142                                                  Kotlin
# 63277                      HTML/CSS;JavaScript;SQL;TypeScript
#
#                                        LanguageWantToWorkWith  \
# ResponseId
# 14                                                     Python
# 30               C#;HTML/CSS;JavaScript;Kotlin;SQL;TypeScript
# 174                                            Python;SQL;VBA
# 419         Bash/Shell (all shells);Groovy;HTML/CSS;Java;J...
# 1023                                       C#;C++;Python;Rust
# ...                                                       ...
# 60421                                                     NaN
# 60751                             HTML/CSS;JavaScript;PHP;SQL
# 61783                                                     NaN
# 63142                  HTML/CSS;JavaScript;Kotlin;Objective-C
# 63277                      HTML/CSS;JavaScript;SQL;TypeScript
#
#                                               LanguageAdmired  \
# ResponseId
# 14                                                     Python
# 30                                 C#;HTML/CSS;JavaScript;SQL
# 174                                                       NaN
# 419         Bash/Shell (all shells);Groovy;HTML/CSS;Java;J...
# 1023                                       C#;C++;Python;Rust
# ...                                                       ...
# 60421                                                     NaN
# 60751                             HTML/CSS;JavaScript;PHP;SQL
# 61783                                                     NaN
# 63142                                                  Kotlin
# 63277                      HTML/CSS;JavaScript;SQL;TypeScript
#
#                                        DatabaseHaveWorkedWith  \
# ResponseId
# 14                                              MariaDB;MySQL
# 30                        Microsoft SQL Server;MongoDB;SQLite
# 174                                                       NaN
# 419         Firebase Realtime Database;H2;Microsoft Access...
# 1023                                                      NaN
# ...                                                       ...
# 60421       Elasticsearch;MariaDB;Microsoft SQL Server;Mon...
# 60751                                     MariaDB;MySQL;Redis
# 61783                                                   MySQL
# 63142                         Cloud Firestore;SQLite;Supabase
# 63277                         Dynamodb;MongoDB;MySQL;Supabase
#
#                                        DatabaseWantToWorkWith  \
# ResponseId
# 14                                                        NaN
# 30          Cosmos DB;Dynamodb;Elasticsearch;Firebase Real...
# 174                                                       NaN
# 419         Firebase Realtime Database;H2;Microsoft Access...
# 1023                                                      NaN
# ...                                                       ...
# 60421                                                     NaN
# 60751                                     MariaDB;MySQL;Redis
# 61783                                                     NaN
# 63142              Cloud Firestore;Firebase Realtime Database
# 63277                         Dynamodb;MongoDB;MySQL;Supabase
#
#                                               DatabaseAdmired  \
# ResponseId
# 14                                                        NaN
# 30                        Microsoft SQL Server;MongoDB;SQLite
# 174                                                       NaN
# 419         Firebase Realtime Database;H2;Microsoft Access...
# 1023                                                      NaN
# ...                                                       ...
# 60421                                                     NaN
# 60751                                     MariaDB;MySQL;Redis
# 61783                                                     NaN
# 63142                                         Cloud Firestore
# 63277                         Dynamodb;MongoDB;MySQL;Supabase
#
#                                        PlatformHaveWorkedWith  \
# ResponseId
# 14                                                        NaN
# 30                                            Microsoft Azure
# 174                                              Google Cloud
# 419         Amazon Web Services (AWS);Cloudflare;Colocatio...
# 1023                                                      NaN
# ...                                                       ...
# 60421       Amazon Web Services (AWS);Digital Ocean;OpenSt...
# 60751                                                     NaN
# 61783                                                     NaN
# 63142                                                     NaN
# 63277       Amazon Web Services (AWS);Cloudflare;Netlify;V...
#
#                                        PlatformWantToWorkWith  \
# ResponseId
# 14                                                        NaN
# 30          Amazon Web Services (AWS);Firebase;Microsoft A...
# 174                 Amazon Web Services (AWS);Microsoft Azure
# 419         Amazon Web Services (AWS);Cloudflare;Colocatio...
# 1023                                                      NaN
# ...                                                       ...
# 60421                                                     NaN
# 60751                                                     NaN
# 61783                                                     NaN
# 63142                                                     NaN
# 63277       Amazon Web Services (AWS);Cloudflare;Netlify;V...
#
#                                               PlatformAdmired  \
# ResponseId
# 14                                                        NaN
# 30                                            Microsoft Azure
# 174                                                       NaN
# 419         Amazon Web Services (AWS);Cloudflare;Colocatio...
# 1023                                                      NaN
# ...                                                       ...
# 60421                                                     NaN
# 60751                                                     NaN
# 61783                                                     NaN
# 63142                                                     NaN
# 63277       Amazon Web Services (AWS);Cloudflare;Netlify;V...
#
#                                        WebframeHaveWorkedWith  \
# ResponseId
# 14                                                CodeIgniter
# 30          AngularJS;ASP.NET;ASP.NET CORE;jQuery;Node.js;...
# 174                                                       NaN
# 419         Angular;AngularJS;Express;jQuery;Node.js;React...
# 1023                                                      NaN
# ...                                                       ...
# 60421       Angular;AngularJS;jQuery;Laravel;Node.js;React...
# 60751                                                  Vue.js
# 61783                                                   Flask
# 63142                                                     NaN
# 63277       CodeIgniter;Deno;Express;Fastify;Next.js;Node....
#
#                                        WebframeWantToWorkWith  \
# ResponseId
# 14                                                        NaN
# 30          ASP.NET;ASP.NET CORE;Blazor;Express;Next.js;No...
# 174                                                       NaN
# 419         Angular;AngularJS;Express;jQuery;Node.js;React...
# 1023                                                      NaN
# ...                                                       ...
# 60421                                                     NaN
# 60751                                    Node.js;React;Vue.js
# 61783                                                     NaN
# 63142                                                     NaN
# 63277              Deno;Express;Fastify;Next.js;Node.js;React
#
#                                               WebframeAdmired  \
# ResponseId
# 14                                                        NaN
# 30                         ASP.NET;ASP.NET CORE;Node.js;React
# 174                                                       NaN
# 419         Angular;AngularJS;Express;jQuery;Node.js;React...
# 1023                                                      NaN
# ...                                                       ...
# 60421                                                     NaN
# 60751                                                  Vue.js
# 61783                                                     NaN
# 63142                                                     NaN
# 63277              Deno;Express;Fastify;Next.js;Node.js;React
#
#                            EmbeddedHaveWorkedWith EmbeddedWantToWorkWith  \
# ResponseId
# 14                                          CMake                    NaN
# 30                                            NaN                    NaN
# 174                                           NaN                    NaN
# 419                                           NaN                    NaN
# 1023        CMake;Cargo;GNU GCC;LLVM's Clang;MSVC                    NaN
# ...                                           ...                    ...
# 60421                                         NaN                    NaN
# 60751                                         NaN                    NaN
# 61783                                         NaN                    NaN
# 63142                                         NaN                    NaN
# 63277                                         NaN                    NaN
#
#            EmbeddedAdmired                             MiscTechHaveWorkedWith  \
# ResponseId
# 14                     NaN                                                NaN
# 30                     NaN              .NET (5+) ;.NET Framework (1.0 - 4.8)
# 174                    NaN                                                NaN
# 419                    NaN  .NET (5+) ;Capacitor;Electron;Ionic;NumPy;Spri...
# 1023                   NaN                              .NET (5+) ;TensorFlow
# ...                    ...                                                ...
# 60421                  NaN                                   Spring Framework
# 60751                  NaN                                                NaN
# 61783                  NaN                                                NaN
# 63142                  NaN                                                NaN
# 63277                  NaN                               React Native;SwiftUI
#
#                                        MiscTechWantToWorkWith  \
# ResponseId
# 14                                                        NaN
# 30                               .NET (5+) ;.NET MAUI;Flutter
# 174                                                       NaN
# 419         .NET (5+) ;Capacitor;Electron;Ionic;NumPy;Spri...
# 1023                                        .NET (5+) ;OpenGL
# ...                                                       ...
# 60421                                                     NaN
# 60751                                                     NaN
# 61783                                                     NaN
# 63142                                                     NaN
# 63277                                            React Native
#
#                                               MiscTechAdmired  \
# ResponseId
# 14                                                        NaN
# 30                                                 .NET (5+)
# 174                                                       NaN
# 419         .NET (5+) ;Capacitor;Electron;Ionic;NumPy;Spri...
# 1023                                               .NET (5+)
# ...                                                       ...
# 60421                                                     NaN
# 60751                                                     NaN
# 61783                                                     NaN
# 63142                                                     NaN
# 63277                                            React Native
#
#                                       ToolsTechHaveWorkedWith  \
# ResponseId
# 14                                                    Ant;APT
# 30                               NuGet;Visual Studio Solution
# 174                                                       NaN
# 419         Ant;APT;Chef;Chocolatey;Composer;Docker;Gradle...
# 1023                               APT;Visual Studio Solution
# ...                                                       ...
# 60421              Homebrew;Kubernetes;Maven (build tool);npm
# 60751                                     Composer;Kubernetes
# 61783                                                     NaN
# 63142                                                     NaN
# 63277       Docker;Homebrew;npm;pnpm;Pulumi;Vite;Webpack;Yarn
#
#                                       ToolsTechWantToWorkWith  \
# ResponseId
# 14                                                        NaN
# 30          Docker;Kubernetes;npm;NuGet;Terraform;Visual S...
# 174                                                       NaN
# 419         Ant;APT;Chef;Chocolatey;Composer;Docker;Gradle...
# 1023                                                      APT
# ...                                                       ...
# 60421                                                     NaN
# 60751                                     Composer;Kubernetes
# 61783                                                     NaN
# 63142                                                     NaN
# 63277       Docker;Homebrew;npm;pnpm;Pulumi;Vite;Webpack;Yarn
#
#                                              ToolsTechAdmired  ...  \
# ResponseId                                                     ...
# 14                                                        NaN  ...
# 30                               NuGet;Visual Studio Solution  ...
# 174                                                       NaN  ...
# 419         Ant;APT;Chef;Chocolatey;Composer;Docker;Gradle...  ...
# 1023                                                      APT  ...
# ...                                                       ...  ...
# 60421                                                     NaN  ...
# 60751                                     Composer;Kubernetes  ...
# 61783                                                     NaN  ...
# 63142                                                     NaN  ...
# 63277       Docker;Homebrew;npm;pnpm;Pulumi;Vite;Webpack;Yarn  ...
#
#            AINextNo change                              AINextMore integrated  \
# ResponseId
# 14                     NaN                                                NaN
# 30            Writing code                                 Search for answers
# 174                    NaN                                                NaN
# 419                    NaN                                                NaN
# 1023                   NaN                                                NaN
# ...                    ...                                                ...
# 60421                  NaN                                                NaN
# 60751                  NaN  Writing code;Debugging and getting help;Commit...
# 61783                  NaN  Testing code;Committing and reviewing code;Dep...
# 63142                  NaN                                                NaN
# 63277                  NaN                                                NaN
#
#            AINextLess integrated AINextMuch less integrated      AIThreat  \
# ResponseId
# 14                           NaN                        NaN  I'm not sure
# 30                           NaN                        NaN            No
# 174                          NaN                        NaN  I'm not sure
# 419                          NaN                        NaN            No
# 1023                         NaN                        NaN           NaN
# ...                          ...                        ...           ...
# 60421                        NaN                        NaN            No
# 60751                        NaN                        NaN  I'm not sure
# 61783                        NaN                        NaN           Yes
# 63142                        NaN                        NaN            No
# 63277                        NaN                        NaN            No
#
#                                                      AIEthics  \
# ResponseId
# 14          Biased results that do not represent diverse v...
# 30          Circulating misinformation or disinformation;B...
# 174         Missing or incorrect attribution for sources o...
# 419         Circulating misinformation or disinformation;M...
# 1023                                                      NaN
# ...                                                       ...
# 60421       Circulating misinformation or disinformation;R...
# 60751       Circulating misinformation or disinformation;M...
# 61783       Missing or incorrect attribution for sources o...
# 63142       Circulating misinformation or disinformation;M...
# 63277       Biased results that do not represent diverse v...
#
#                                                  AIChallenges TBranch  \
# ResponseId
# 14                                                        NaN     NaN
# 30          Don’t trust the output or answers;Not everyone...      No
# 174         Don’t trust the output or answers;AI tools lac...     Yes
# 419         Don’t trust the output or answers;AI tools lac...     NaN
# 1023                                                      NaN     NaN
# ...                                                       ...     ...
# 60421                                  Not everyone uses them     Yes
# 60751       AI tools lack context of codebase,  internal a...     NaN
# 61783                                                     NaN     NaN
# 63142       Don’t trust the output or answers;Lack of prop...     NaN
# 63277       We don’t have the right policies in place to r...     Yes
#
#                             ICorPM WorkExp                 Knowledge_1  \
# ResponseId
# 14                             NaN     NaN                         NaN
# 30                             NaN     NaN                         NaN
# 174         Individual contributor     1.0  Neither agree nor disagree
# 419                            NaN     NaN                         NaN
# 1023                           NaN     NaN                         NaN
# ...                            ...     ...                         ...
# 60421       Individual contributor     9.0                         NaN
# 60751                          NaN     NaN                         NaN
# 61783                          NaN     NaN                         NaN
# 63142                          NaN     NaN                         NaN
# 63277       Individual contributor     6.0                       Agree
#
#            Knowledge_2 Knowledge_3                 Knowledge_4 Knowledge_5  \
# ResponseId
# 14                 NaN         NaN                         NaN         NaN
# 30                 NaN         NaN                         NaN         NaN
# 174           Disagree       Agree  Neither agree nor disagree       Agree
# 419                NaN         NaN                         NaN         NaN
# 1023               NaN         NaN                         NaN         NaN
# ...                ...         ...                         ...         ...
# 60421              NaN         NaN                         NaN         NaN
# 60751              NaN         NaN                         NaN         NaN
# 61783              NaN         NaN                         NaN         NaN
# 63142              NaN         NaN                         NaN         NaN
# 63277            Agree       Agree                       Agree       Agree
#
#                            Knowledge_6                 Knowledge_7  \
# ResponseId
# 14                                 NaN                         NaN
# 30                                 NaN                         NaN
# 174         Neither agree nor disagree  Neither agree nor disagree
# 419                                NaN                         NaN
# 1023                               NaN                         NaN
# ...                                ...                         ...
# 60421                              NaN                         NaN
# 60751                              NaN                         NaN
# 61783                              NaN                         NaN
# 63142                              NaN                         NaN
# 63277                            Agree                       Agree
#
#                            Knowledge_8        Knowledge_9       Frequency_1  \
# ResponseId
# 14                                 NaN                NaN               NaN
# 30                                 NaN                NaN               NaN
# 174         Neither agree nor disagree  Strongly disagree             Never
# 419                                NaN                NaN               NaN
# 1023                               NaN                NaN               NaN
# ...                                ...                ...               ...
# 60421                              NaN                NaN               NaN
# 60751                              NaN                NaN               NaN
# 61783                              NaN                NaN               NaN
# 63142                              NaN                NaN               NaN
# 63277                            Agree              Agree  1-2 times a week
#
#                  Frequency_2       Frequency_3        TimeSearching  \
# ResponseId
# 14                       NaN               NaN                  NaN
# 30                       NaN               NaN                  NaN
# 174         3-5 times a week             Never  15-30 minutes a day
# 419                      NaN               NaN                  NaN
# 1023                     NaN               NaN                  NaN
# ...                      ...               ...                  ...
# 60421                    NaN               NaN                  NaN
# 60751                    NaN               NaN                  NaN
# 61783                    NaN               NaN                  NaN
# 63142                    NaN               NaN                  NaN
# 63277       1-2 times a week  1-2 times a week  15-30 minutes a day
#
#                   TimeAnswering  \
# ResponseId
# 14                          NaN
# 30                          NaN
# 174         15-30 minutes a day
# 419                         NaN
# 1023                        NaN
# ...                         ...
# 60421                       NaN
# 60751                       NaN
# 61783                       NaN
# 63142                       NaN
# 63277       15-30 minutes a day
#
#                                                   Frustration  \
# ResponseId
# 14                                                        NaN
# 30                                                        NaN
# 174         Complexity of tech stack for deployment;Comple...
# 419                                                       NaN
# 1023                                                      NaN
# ...                                                       ...
# 60421                                                     NaN
# 60751                                                     NaN
# 61783                                                     NaN
# 63142                                                     NaN
# 63277       Amount of technical debt;Number of software to...
#
#                                              ProfessionalTech  \
# ResponseId
# 14                                                        NaN
# 30                                                        NaN
# 174         Knowledge sharing community;AI-assisted techno...
# 419                                                       NaN
# 1023                                                      NaN
# ...                                                       ...
# 60421                                                     NaN
# 60751                                                     NaN
# 61783                                                     NaN
# 63142                                                     NaN
# 63277                                           Microservices
#
#                              ProfessionalCloud  \
# ResponseId
# 14                                         NaN
# 30                                         NaN
# 174         Cloud only (single or multi-cloud)
# 419                                        NaN
# 1023                                       NaN
# ...                                        ...
# 60421                                      NaN
# 60751                                      NaN
# 61783                                      NaN
# 63142                                      NaN
# 63277       Cloud only (single or multi-cloud)
#
#                         ProfessionalQuestion  \
# ResponseId
# 14                                       NaN
# 30                                       NaN
# 174         Traditional public search engine
# 419                                      NaN
# 1023                                     NaN
# ...                                      ...
# 60421                                    NaN
# 60751                                    NaN
# 61783                                    NaN
# 63142                                    NaN
# 63277       Traditional public search engine
#
#                                               Industry JobSatPoints_1  \
# ResponseId
# 14                                                 NaN            NaN
# 30                                                 NaN            NaN
# 174         Internet, Telecomm or Information Services           10.0
# 419                                                NaN            NaN
# 1023                                               NaN            NaN
# ...                                                ...            ...
# 60421                                              NaN            NaN
# 60751                                              NaN            NaN
# 61783                                              NaN            NaN
# 63142                                              NaN            NaN
# 63277                                          Fintech            0.0
#
#            JobSatPoints_4 JobSatPoints_5 JobSatPoints_6 JobSatPoints_7  \
# ResponseId
# 14                    NaN            NaN            NaN            NaN
# 30                    NaN            NaN            NaN            NaN
# 174                   8.0           10.0           10.0           10.0
# 419                   NaN            NaN            NaN            NaN
# 1023                  NaN            NaN            NaN            NaN
# ...                   ...            ...            ...            ...
# 60421                 NaN            NaN            NaN            NaN
# 60751                 NaN            NaN            NaN            NaN
# 61783                 NaN            NaN            NaN            NaN
# 63142                 NaN            NaN            NaN            NaN
# 63277                 0.0            0.0            0.0            0.0
#
#            JobSatPoints_8 JobSatPoints_9 JobSatPoints_10 JobSatPoints_11  \
# ResponseId
# 14                    NaN            NaN             NaN             NaN
# 30                    NaN            NaN             NaN             NaN
# 174                   9.0           10.0            10.0             8.0
# 419                   NaN            NaN             NaN             NaN
# 1023                  NaN            NaN             NaN             NaN
# ...                   ...            ...             ...             ...
# 60421                 NaN            NaN             NaN             NaN
# 60751                 NaN            NaN             NaN             NaN
# 61783                 NaN            NaN             NaN             NaN
# 63142                 NaN            NaN             NaN             NaN
# 63277                 0.0            0.0             0.0             0.0
#
#                      SurveyLength                  SurveyEase  \
# ResponseId
# 14                       Too long  Neither easy nor difficult
# 30          Appropriate in length                        Easy
# 174                      Too long  Neither easy nor difficult
# 419                      Too long                        Easy
# 1023        Appropriate in length                        Easy
# ...                           ...                         ...
# 60421                         NaN                         NaN
# 60751                    Too long  Neither easy nor difficult
# 61783                         NaN                         NaN
# 63142                         NaN                         NaN
# 63277                    Too long                   Difficult
#
#            ConvertedCompYearly JobSat
# ResponseId
# 14                         NaN    NaN
# 30                         NaN    NaN
# 174                        NaN    5.0
# 419                        NaN    NaN
# 1023                       NaN    NaN
# ...                        ...    ...
# 60421                      NaN    NaN
# 60751                      NaN    NaN
# 61783                      NaN    NaN
# 63142                      NaN    NaN
# 63277                      NaN    8.0
#
# [196 rows x 113 columns]

# %%
filt = df['Country'] == 'Philippines'
df.loc[filt]['DevType'].value_counts()
# Out:
# DevType
# Developer, full-stack                            79
# Student                                          23
# Developer, back-end                              19
# Developer, front-end                             16
# Other (please specify):                          13
# Developer, mobile                                 8
# Cloud infrastructure engineer                     4
# Developer, desktop or enterprise applications     4
# Data or business analyst                          3
# Academic researcher                               3
# DevOps specialist                                 3
# System administrator                              2
# Engineering manager                               2
# Developer, game or graphics                       2
# Database administrator                            2
# Engineer, site reliability                        2
# Developer, AI                                     2
# Product manager                                   1
# Developer, QA or test                             1
# Data scientist or machine learning specialist     1
# Scientist                                         1
# Project manager                                   1
# Security professional                             1
# Research & Development role                       1
# Senior Executive (C-Suite, VP, etc.)              1
# Name: count, dtype: int64

# %%
country_grp['DevType'].value_counts().head(50)
# Out:
# Country      DevType
# Afghanistan  Developer, full-stack                            11
#              Student                                           6
#              Academic researcher                               4
#              Data engineer                                     3
#              Developer, back-end                               3
#              Blockchain                                        2
#              Data scientist or machine learning specialist     2
#              Developer, embedded applications or devices       2
#              Developer, mobile                                 2
#              Other (please specify):                           2
#              Security professional                             2
#              Cloud infrastructure engineer                     1
#              Database administrator                            1
#              DevOps specialist                                 1
#              Developer, desktop or enterprise applications     1
#              Developer, front-end                              1
#              Educator                                          1
#              Engineering manager                               1
#              Product manager                                   1
#              Scientist                                         1
#              System administrator                              1
# Albania      Developer, full-stack                            16
#              Developer, back-end                              10
#              Student                                           5
#              Security professional                             3
#              Academic researcher                               2
#              DevOps specialist                                 2
#              Developer, front-end                              2
#              Senior Executive (C-Suite, VP, etc.)              2
#              Cloud infrastructure engineer                     1
#              Designer                                          1
#              Developer, AI                                     1
#              Developer, QA or test                             1
#              Developer, desktop or enterprise applications     1
# Algeria      Developer, full-stack                            29
#              Developer, front-end                              9
#              Student                                           9
#              Developer, back-end                               5
#              Developer, mobile                                 4
#              Developer, desktop or enterprise applications     3
#              Data or business analyst                          2
#              Educator                                          2
#              Other (please specify):                           2
#              Academic researcher                               1
#              Data scientist or machine learning specialist     1
#              Designer                                          1
#              Developer, QA or test                             1
#              Project manager                                   1
#              Security professional                             1
#              Senior Executive (C-Suite, VP, etc.)              1
# Name: count, dtype: int64

# %%
country_grp['DevType'].value_counts().loc['Philippines']
# Out:
# DevType
# Developer, full-stack                            79
# Student                                          23
# Developer, back-end                              19
# Developer, front-end                             16
# Other (please specify):                          13
# Developer, mobile                                 8
# Cloud infrastructure engineer                     4
# Developer, desktop or enterprise applications     4
# Academic researcher                               3
# Data or business analyst                          3
# DevOps specialist                                 3
# Database administrator                            2
# Developer, AI                                     2
# Developer, game or graphics                       2
# Engineer, site reliability                        2
# Engineering manager                               2
# System administrator                              2
# Data scientist or machine learning specialist     1
# Developer, QA or test                             1
# Product manager                                   1
# Project manager                                   1
# Research & Development role                       1
# Scientist                                         1
# Security professional                             1
# Senior Executive (C-Suite, VP, etc.)              1
# Name: count, dtype: int64

# %%
country_grp['DevType'].value_counts(normalize=True).loc['Philippines']
# Out:
# DevType
# Developer, full-stack                            0.405128
# Student                                          0.117949
# Developer, back-end                              0.097436
# Developer, front-end                             0.082051
# Other (please specify):                          0.066667
# Developer, mobile                                0.041026
# Cloud infrastructure engineer                    0.020513
# Developer, desktop or enterprise applications    0.020513
# Academic researcher                              0.015385
# Data or business analyst                         0.015385
# DevOps specialist                                0.015385
# Database administrator                           0.010256
# Developer, AI                                    0.010256
# Developer, game or graphics                      0.010256
# Engineer, site reliability                       0.010256
# Engineering manager                              0.010256
# System administrator                             0.010256
# Data scientist or machine learning specialist    0.005128
# Developer, QA or test                            0.005128
# Product manager                                  0.005128
# Project manager                                  0.005128
# Research & Development role                      0.005128
# Scientist                                        0.005128
# Security professional                            0.005128
# Senior Executive (C-Suite, VP, etc.)             0.005128
# Name: proportion, dtype: float64

# %%
country_grp['CompTotal'].median().loc['Philippines']
# Out:
# np.float64(720000.0)

# %%
country_grp['CompTotal'].agg(['median', 'mean']).loc['Canada']
# Out:
# median    120000.000000
# mean      177999.189548
# Name: Canada, dtype: float64

# %%
filt = df['Country'] == 'Philippines'
df.loc[filt]['LanguageHaveWorkedWith'].str.contains('Python').sum()
# Out:
# 83

# %%
country_grp['LanguageHaveWorkedWith'].str.contains('Python').sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 country_grp['LanguageHaveWorkedWith'].str.contains('Python').sum()
#
# File ~\.virtualenvs\pandas-6pjP2pVR\lib\site-packages\pandas\core\groupby\groupby.py:1363, in GroupBy.__getattr__(self, attr)
#    1360 if attr in self.obj:
#    1361     return self[attr]
# -> 1363 raise AttributeError(
#    1364     f"'{type(self).__name__}' object has no attribute '{attr}'"
#    1365 )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'str'

# %%
country_grp['LanguageHaveWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              26
# Albania                                  10
# Algeria                                  37
# Andorra                                   8
# Angola                                    9
#                                        ...
# Venezuela, Bolivarian Republic of...     25
# Viet Nam                                138
# Yemen                                    10
# Zambia                                    8
# Zimbabwe                                 17
# Name: LanguageHaveWorkedWith, Length: 185, dtype: int64

# %%
country_grp['LanguageHaveWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              26
# Albania                                  10
# Algeria                                  37
# Andorra                                   8
# Angola                                    9
#                                        ...
# Venezuela, Bolivarian Republic of...     25
# Viet Nam                                138
# Yemen                                    10
# Zambia                                    8
# Zimbabwe                                 17
# Name: LanguageHaveWorkedWith, Length: 185, dtype: int64

# %%
country_respondent = df['Country'].value_counts()
country_respondent
# Out:
# Country
# United States of America                                11095
# Germany                                                  4947
# India                                                    4231
# United Kingdom of Great Britain and Northern Ireland     3224
# Ukraine                                                  2672
#                                                         ...
# Micronesia, Federated States of...                          1
# Nauru                                                       1
# Chad                                                        1
# Djibouti                                                    1
# Solomon Islands                                             1
# Name: count, Length: 185, dtype: int64

# %%
country_uses_python = country_grp['LanguageHaveWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
country_uses_python
# Out:
# Country
# Afghanistan                              26
# Albania                                  10
# Algeria                                  37
# Andorra                                   8
# Angola                                    9
#                                        ...
# Venezuela, Bolivarian Republic of...     25
# Viet Nam                                138
# Yemen                                    10
# Zambia                                    8
# Zimbabwe                                 17
# Name: LanguageHaveWorkedWith, Length: 185, dtype: int64

# %%
python_df = pd.concat([country_respondent, country_uses_python], axis='columns', sort=False)

# %%
python_df
# Out:
#                                                     count  \
# Country
# United States of America                            11095
# Germany                                              4947
# India                                                4231
# United Kingdom of Great Britain and Northern Ir...   3224
# Ukraine                                              2672
# ...                                                   ...
# Micronesia, Federated States of...                      1
# Nauru                                                   1
# Chad                                                    1
# Djibouti                                                1
# Solomon Islands                                         1
#
#                                                     LanguageHaveWorkedWith
# Country
# United States of America                                              6251
# Germany                                                               2647
# India                                                                 2128
# United Kingdom of Great Britain and Northern Ir...                    1638
# Ukraine                                                                963
# ...                                                                    ...
# Micronesia, Federated States of...                                       0
# Nauru                                                                    0
# Chad                                                                     1
# Djibouti                                                                 0
# Solomon Islands                                                          0
#
# [185 rows x 2 columns]

# %%
python_df.rename(columns={'count':'NumRespondents', 'LanguageHaveWorkedWith':'NumKnowsPython'}, inplace=True)

# %%
python_df
# Out:
#                                                     NumRespondents  \
# Country
# United States of America                                     11095
# Germany                                                       4947
# India                                                         4231
# United Kingdom of Great Britain and Northern Ir...            3224
# Ukraine                                                       2672
# ...                                                            ...
# Micronesia, Federated States of...                               1
# Nauru                                                            1
# Chad                                                             1
# Djibouti                                                         1
# Solomon Islands                                                  1
#
#                                                     NumKnowsPython
# Country
# United States of America                                      6251
# Germany                                                       2647
# India                                                         2128
# United Kingdom of Great Britain and Northern Ir...            1638
# Ukraine                                                        963
# ...                                                            ...
# Micronesia, Federated States of...                               0
# Nauru                                                            0
# Chad                                                             1
# Djibouti                                                         0
# Solomon Islands                                                  0
#
# [185 rows x 2 columns]

# %%
python_df['PctKnowsPython'] = (python_df['NumKnowsPython']/python_df['NumRespondents']) * 100
python_df
# Out:
#                                                     NumRespondents  \
# Country
# United States of America                                     11095
# Germany                                                       4947
# India                                                         4231
# United Kingdom of Great Britain and Northern Ir...            3224
# Ukraine                                                       2672
# ...                                                            ...
# Micronesia, Federated States of...                               1
# Nauru                                                            1
# Chad                                                             1
# Djibouti                                                         1
# Solomon Islands                                                  1
#
#                                                     NumKnowsPython  \
# Country
# United States of America                                      6251
# Germany                                                       2647
# India                                                         2128
# United Kingdom of Great Britain and Northern Ir...            1638
# Ukraine                                                        963
# ...                                                            ...
# Micronesia, Federated States of...                               0
# Nauru                                                            0
# Chad                                                             1
# Djibouti                                                         0
# Solomon Islands                                                  0
#
#                                                     PctKnowsPython
# Country
# United States of America                                 56.340694
# Germany                                                  53.507176
# India                                                    50.295438
# United Kingdom of Great Britain and Northern Ir...       50.806452
# Ukraine                                                  36.040419
# ...                                                            ...
# Micronesia, Federated States of...                        0.000000
# Nauru                                                     0.000000
# Chad                                                    100.000000
# Djibouti                                                  0.000000
# Solomon Islands                                           0.000000
#
# [185 rows x 3 columns]

# %%
python_df.sort_values(by='PctKnowsPython', ascending=False, inplace=True)

# %%
python_df.head(50)
# Out:
#                                   NumRespondents  NumKnowsPython  \
# Country
# Belize                                         2               2
# Brunei Darussalam                              3               3
# Dominica                                       1               1
# Samoa                                          1               1
# Central African Republic                       1               1
# Niger                                          1               1
# Chad                                           1               1
# Lesotho                                        1               1
# Saint Kitts and Nevis                          1               1
# Mauritania                                     5               4
# Congo, Republic of the...                      8               6
# Libyan Arab Jamahiriya                         4               3
# Liberia                                        4               3
# Guyana                                         3               2
# Democratic Republic of the Congo               3               2
# Monaco                                         3               2
# Bhutan                                         3               2
# North Korea                                    3               2
# Sierra Leone                                   3               2
# Zimbabwe                                      26              17
# El Salvador                                   19              12
# Kuwait                                         8               5
# Singapore                                    177             110
# Israel                                       604             360
# South Korea                                  146              87
# Rwanda                                        22              13
# Uganda                                        39              23
# Kenya                                        180             106
# Morocco                                       98              57
# Iceland                                       31              18
# Japan                                        288             167
# Chile                                        133              77
# China                                        406             233
# Tajikistan                                     7               4
# Sudan                                          7               4
# Mozambique                                     7               4
# United States of America                   11095            6251
# France                                      2110            1187
# Maldives                                      16               9
# Yemen                                         18              10
# Luxembourg                                    40              22
# Turkmenistan                                  11               6
# Ireland                                      270             147
# Guatemala                                     41              22
# Finland                                      386             207
# Germany                                     4947            2647
# Sri Lanka                                    163              87
# Andorra                                       15               8
# Zambia                                        15               8
# Canada                                      2104            1120
#
#                                   PctKnowsPython
# Country
# Belize                                100.000000
# Brunei Darussalam                     100.000000
# Dominica                              100.000000
# Samoa                                 100.000000
# Central African Republic              100.000000
# Niger                                 100.000000
# Chad                                  100.000000
# Lesotho                               100.000000
# Saint Kitts and Nevis                 100.000000
# Mauritania                             80.000000
# Congo, Republic of the...              75.000000
# Libyan Arab Jamahiriya                 75.000000
# Liberia                                75.000000
# Guyana                                 66.666667
# Democratic Republic of the Congo       66.666667
# Monaco                                 66.666667
# Bhutan                                 66.666667
# North Korea                            66.666667
# Sierra Leone                           66.666667
# Zimbabwe                               65.384615
# El Salvador                            63.157895
# Kuwait                                 62.500000
# Singapore                              62.146893
# Israel                                 59.602649
# South Korea                            59.589041
# Rwanda                                 59.090909
# Uganda                                 58.974359
# Kenya                                  58.888889
# Morocco                                58.163265
# Iceland                                58.064516
# Japan                                  57.986111
# Chile                                  57.894737
# China                                  57.389163
# Tajikistan                             57.142857
# Sudan                                  57.142857
# Mozambique                             57.142857
# United States of America               56.340694
# France                                 56.255924
# Maldives                               56.250000
# Yemen                                  55.555556
# Luxembourg                             55.000000
# Turkmenistan                           54.545455
# Ireland                                54.444444
# Guatemala                              53.658537
# Finland                                53.626943
# Germany                                53.507176
# Sri Lanka                              53.374233
# Andorra                                53.333333
# Zambia                                 53.333333
# Canada                                 53.231939

# %%
python_df.loc['Japan']
# Out:
# NumRespondents    288.000000
# NumKnowsPython    167.000000
# PctKnowsPython     57.986111
# Name: Japan, dtype: float64
